# %%
import numpy as np

def jacobi(A, b, x0, tol=1e-8, max_iterations=1000):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)
    x = np.array(x0, dtype=float).copy()
    
    n = len(b)
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)

        for i in range(n):
            s = sum(A[i, j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i, i]

        # Check for convergence (infinity norm)
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1  # iterations used

        x = x_new

    return x, max_iterations

# %%
import numpy as np

def gauss_seidel(A, b, x0, tol=1e-8, max_iterations=1000):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)
    x = np.array(x0, dtype=float).copy()
    
    n = len(b)
    
    for k in range(max_iterations):
        x_new = x.copy()

        for i in range(n):
            s1 = sum(A[i, j] * x_new[j] for j in range(i))       # updated values
            s2 = sum(A[i, j] * x[j] for j in range(i + 1, n))    # old values
            x_new[i] = (b[i] - s1 - s2) / A[i, i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1

        x = x_new

    return x, max_iterations

# %%
import numpy as np
import time

# Challange 6a
A = np.array([
    [10, -1,  2,  0,  0],
    [-1, 11, -1,  3,  0],
    [ 2, -1, 10, -1,  0],
    [ 0,  3, -1,  8, -2],
    [ 0,  0,  0, -2,  9]
])

b = np.array([14, 30, 26, 25, 37])

x0 = np.zeros(5)
tol = 1e-6
max_iter = 10000


#Jacobi
start = time.time()
x_j, it_j = jacobi(A, b, x0, tol, max_iter)
end = time.time()

print("Jacobi result:")
print(x_j)
print("Iterations:", it_j)
print("Time:", end - start)


#Gauss-Seidel
start = time.time()
x_gs, it_gs = gauss_seidel(A, b, x0, tol, max_iter)
end = time.time()

print("\nGauss-Seidel result:")
print(x_gs)
print("Iterations:", it_gs)
print("Time:", end - start)
# Out:
# Jacobi result:
# [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 19
# Time: 0.0012917518615722656
#
# Gauss-Seidel result:
# [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 11
# Time: 0.0007195472717285156

# %%
import numpy as np
import time

# Challange 6b
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)

x0 = np.zeros(5)
tol = 1e-6
max_iter = 10000


# Jacobi
start = time.time()
x_j, it_j = jacobi(A, b, x0, tol, max_iter)
end = time.time()

print("Jacobi result:")
print(x_j)
print("Iterations:", it_j)
print("Time:", end - start)


# Gauss-Seidel
start = time.time()
x_gs, it_gs = gauss_seidel(A, b, x0, tol, max_iter)
end = time.time()

print("\nGauss-Seidel result:")
print(x_gs)
print("Iterations:", it_gs)
print("Time:", end - start)
# Out:
# <ipython-input-2-498c1102556b>:14: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i, j] * x[j] for j in range(n) if j != i)
# <ipython-input-2-498c1102556b>:14: RuntimeWarning: invalid value encountered in double_scalars
#   s = sum(A[i, j] * x[j] for j in range(n) if j != i)
# Jacobi result:
# [nan nan nan nan nan]
# Iterations: 10000
# Time: 0.407196044921875
# <ipython-input-8-c0d347dc698d>:15: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i, j] * x[j] for j in range(i + 1, n))    # old values
# <ipython-input-8-c0d347dc698d>:15: RuntimeWarning: invalid value encountered in double_scalars
#   s2 = sum(A[i, j] * x[j] for j in range(i + 1, n))    # old values
# Gauss-Seidel result:
# [nan nan nan nan nan]
# Iterations: 10000
# Time: 0.3669452667236328

# %%
# "How should I structure a Jacobi and Gauss-Seidel method in Python
# with a tolerance and maximum iteration condition?"
#
# Asked for guidance on organizing the iteration loop and convergence check and syntax
# Used ChatGPT
