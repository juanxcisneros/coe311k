# %%
n = 11
i = 1
while i <= n:
    i *= 2
i //= 2

while i > 0:
    if n >= i:
        print(1, end="")
        n -= i
    else:
        print(0, end="")
    i //= 2
print()
print(" ")

# %%
print(1, end="")
print(0, end="")
print(1)
