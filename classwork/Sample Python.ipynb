# %% [markdown]
# I'm about to write down my first Jupyter Notebook in Python

# %%
print ("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2 * np.pi, 50)
plt.subplot(2, 1, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), 'g')
plt.subplot(2,1,1)
plt.plot(x, np.arcsin(x), 'b')
plt.show()
# Out:
# <ipython-input-7-969bc8dedd30>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,1,1)
# <ipython-input-7-969bc8dedd30>:9: RuntimeWarning: invalid value encountered in arcsin
#   plt.plot(x, np.arcsin(x), 'b')

# %%
y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()
plt.show()

# %%
z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im,
orientation='horizontal')
plt.show(fig)

# %%
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    i = i + 1
    j = 0
for y in np.arange(-10,10,.01):
    j = j + 1
z[i][j] = x*x + y*y

# %%
def f1(x,y):
    return (x*x+y*y)
x = np.linspace(-10, 10, 2000)
y = np.linspace(-10, 10, 2000)
X, Y = np.meshgrid(x, y)
Z = f1(X, Y)

# %%
print (Z)
# Out:
# [[200.         199.80000005 199.6002003  ... 199.6002003  199.80000005
#   200.        ]
#  [199.80000005 199.6000001  199.40020035 ... 199.40020035 199.6000001
#   199.80000005]
#  [199.6002003  199.40020035 199.2004006  ... 199.2004006  199.40020035
#   199.6002003 ]
#  ...
#  [199.6002003  199.40020035 199.2004006  ... 199.2004006  199.40020035
#   199.6002003 ]
#  [199.80000005 199.6000001  199.40020035 ... 199.40020035 199.6000001
#   199.80000005]
#  [200.         199.80000005 199.6002003  ... 199.6002003  199.80000005
#   200.        ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(90, 0)
